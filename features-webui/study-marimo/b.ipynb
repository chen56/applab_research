# %%
import marimo as mo


mo.md("ssssss")
# Out:
# _md()

# %%
import os
import datetime
print(datetime.datetime.now())
os.getcwd()
# Out:
# 2025-12-26 18:31:44.678972
# '/Users/chen/git/chen56/apphub_research/study/study-marimo'

# %%
slider = mo.ui.slider(1, 22)
slider
# Out:
# slider()

# %%
slider.value
# Out:
# 1
