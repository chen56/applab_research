# %%
# !uv pip install gradio

# %%
import gradio as gr
with gr.Blocks(theme=gr.themes.Monochrome(),title="ssss") as demo2:
    t = gr.Textbox()
    # demo.load(lambda : "Loaded", None, t)

with gr.Blocks(theme=gr.themes.Soft(),title="asdfasdf") as demo:
    # Navbar for the main page
    navbar = gr.Navbar(
        visible=True,
        main_page_name="Dashboard",
        value=[("About", "https://example.com/about")]
    )
    
    gr.Textbox(label="Main page content")

with demo.route("Settings"):
    # Different navbar for the Settings page
    navbar = gr.Navbar(
        visible=True,
        main_page_name="Home",
        value=[("Documentation", "https://docs.example.com")]
    )
    gr.Textbox(label="Settings page")

with demo.route("Settings2"):
    # Different navbar for the Settings page
    navbar = gr.Navbar(
        visible=True,
        main_page_name="Home",
        value=[("Documentation", "https://docs.example.com")]
    )
    demo2.render()
    gr.Textbox(label="Settings2 page")

demo.launch()
# Out:
# /var/folders/yf/26fdq7553mg3b35j7xrklkjw0000gn/T/ipykernel_10410/530973033.py:2: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme. Please pass these parameters to launch() instead.
#   with gr.Blocks(theme=gr.themes.Monochrome(),title="ssss") as demo2:
# /var/folders/yf/26fdq7553mg3b35j7xrklkjw0000gn/T/ipykernel_10410/530973033.py:6: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme. Please pass these parameters to launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft(),title="asdfasdf") as demo:
# * Running on local URL:  http://127.0.0.1:7874
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7874/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
