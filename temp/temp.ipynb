# %%
# Out:
# <marimo._server.asgi.create_asgi_app.<locals>.Builder at 0x117662f90>

# %%
# 安装依赖（如果还没安装）
# !pip install ipysheet pandas IPython

import ipysheet
import pandas as pd
from IPython.display import display, Markdown, clear_output

# Step 1: 初始表格数据
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 22],
    "City": ["NY", "LA", "SF"]
}
df = pd.DataFrame(data)

# Step 2: 创建 ipysheet 工作表
sheet = ipysheet.from_dataframe(df)
display(sheet)

# Step 3: 创建按钮用来生成 Markdown 并显示
import ipywidgets as widgets

def update_markdown(b):
    new_df = ipysheet.to_dataframe(sheet)  # 从表格获取新数据
    md = new_df.to_markdown(index=False)   # 转成 Markdown 表格
    clear_output(wait=True)
    display(sheet)
    display(button)
    display(Markdown("### Markdown Table Output:"))
    display(Markdown(md))

button = widgets.Button(description="Generate Markdown")
button.on_click(update_markdown)
display(button)
# Out:
# Sheet(cells=(Cell(column_end=0, column_start=0, numeric_format=None, row_end=2, row_start=0, squeeze_row=False…
# Button(description='Generate Markdown', style=ButtonStyle())
# ### Markdown Table Output:
# | Name    |   Age | City   |
# |:--------|------:|:-------|
# | Alice   |    25 | NY     |
# | Bob     |    30 | LA     |
# | Charlie |    22 | SF     |
